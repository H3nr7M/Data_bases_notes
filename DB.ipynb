# %% [markdown]
# <a href="https://colab.research.google.com/github/H3nr7M/Data_bases_notes/blob/main/DB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data bases notes
# hello I want to share a little of what I know about databases since the information that exists is a lot I hope and these notes will serve you

# %% [markdown]
# Various database paradigms
# ---
# * Relational
#    * mysql
#    * POSTGRESQL
#    * DB2 (IBM)
#    * Oracle (PL SQL)
#    * MS SQL Server (Microsoft SQL Server)
# * non-relational
#    1. Key value
#      * redis
#    2. Wide column
#      * Apache hbase
#    3. Document
#      * Mongo DB
#      * Firebase
#    4.  Graphic
#      * neo4j
#    5. Search
#      * elastic, meilisearch
#    6. Multi-model
#      * Fauna

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot from 2022-09-02 17-41-23.png](data:image/png;base64,...)

# %% [markdown]
# ###SQL
# ####Basic commands
# * SELECT - extracts data from a database
#   * SELECT column1, column2, ...
# FROM table_name WHERE condition;
# * UPDATE - updates data in a database
#   * UPDATE Customers
# SET ContactName = 'Alfred Schmidt', City= 'Frankfurt'
# WHERE CustomerID = 1;
# * DELETE - deletes data from a database
#   * DELETE FROM Customers WHERE CustomerName='Alfreds Futterkiste';
# * INSERT INTO - inserts new data into a database
#   * INSERT INTO table_name (column1, column2, column3, ...)
# VALUES (value1, value2, value3, ...);
# * CREATE DATABASE - creates a new database
#   * CREATE DATABASE databasename;
# * CREATE TABLE - creates a new table
#   * CREATE TABLE Persons (
#     PersonID int,
#     LastName varchar(255),
#     FirstName varchar(255),
#     Address varchar(255),
#     City varchar(255)
# );
# * ALTER TABLE - modifies a table
#   * ALTER TABLE table_name
# ADD column_name datatype;
# * DROP TABLE - deletes a table
# * CREATE INDEX - creates an index (search key)
# * DROP INDEX - deletes an index

# %% [markdown]
# ###Others
# * join
# * left join
# * right join
# * inner join

# %% [markdown]
# ###Reserved words
# * distinct (prevent duplicate rows from being selected.)
# * order by (asc, desc)
# * Operations with strings
#   * left/right (city,1) in('a','e','i','o','u') return first latter in city in the range, like "a%" or return (find a pattern specified in a column.), concat, substring (str, start, end), lower, REPLICATE(string, integer), union all,
# * not, and, or,
# * Operations with int
#    * floor (rounded to integer) or ceil (rounded to integer) or ROUND(x),2)
# SQRT, POWER, min, max, abs, avg, sum, count,
# * group by having count
# * SELECT CASE WHEN THEN end
# * Programming in SQL
#    * WHILE (begin, end), print
#    * variables
#      * DECLARE, SET
